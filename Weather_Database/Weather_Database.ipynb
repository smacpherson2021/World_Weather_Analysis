# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | huilong
# Processing Record 7 of Set 1 | ketchikan
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | kanker
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | olga
# Processing Record 16 of Set 1 | sacramento
# Processing Record 17 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | sola
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | aklavik
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | grindavik
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | lahij
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | olafsvik
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | gerede
# Processing Record 36 of Set 1 | hohhot
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | mormugao
# Processing Record 41 of Set 1 | lompoc
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | jammu
# Processing Record 44 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 1 | ballina
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | nuuk
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | srednekolymsk
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | matina
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | touros
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | coihaique
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | ruteng
# Processing Record 10 of Set 2 | velikooktyabrskiy
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | hobyo
# Processing Record 14 of Set 2 | los llanos de aridane
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 2 | kattivakkam
# Processing Record 18 of Set 2 | george town
# Processing Record 19 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 2 | sisimiut
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | dukat
# Processing Record 24 of Set 2 | kiev
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | puerto escondido
# Processing Record 27 of Set 2 | tigil
# Processing Record 28 of Set 2 | leningradskiy
# Processing Record 29 of Set 2 | la asuncion
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | shimoda
# Processing Record 33 of Set 2 | georgiyevka
# Processing Record 34 of Set 2 | rosario
# Processing Record 35 of Set 2 | pahalgam
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | nanortalik
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | polessk
# Processing Record 44 of Set 2 | mount gambier
# Processing Record 45 of Set 2 | pandan
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | zheleznodorozhnyy
# Processing Record 50 of Set 2 | rio grande
# Processing Record 1 of Set 3 | bulgan
# Processing Record 2 of Set 3 | toucheng
# Processing Record 3 of Set 3 | ada
# Processing Record 4 of Set 3 | tukrah
# Processing Record 5 of Set 3 | hay river
# Processing Record 6 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 3 | west odessa
# Processing Record 8 of Set 3 | konevo
# Processing Record 9 of Set 3 | abha
# Processing Record 10 of Set 3 | papasquiaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | otacilio costa
# Processing Record 12 of Set 3 | alofi
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | burkburnett
# Processing Record 15 of Set 3 | goundam
# Processing Record 16 of Set 3 | tarbagatay
# Processing Record 17 of Set 3 | puerto maldonado
# Processing Record 18 of Set 3 | ngunguru
# Processing Record 19 of Set 3 | wanning
# Processing Record 20 of Set 3 | panjwin
# City not found. Skipping...
# Processing Record 21 of Set 3 | laramie
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | along
# Processing Record 25 of Set 3 | tilichiki
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | jian
# Processing Record 29 of Set 3 | lima
# Processing Record 30 of Set 3 | aykhal
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | juba
# Processing Record 34 of Set 3 | mezen
# Processing Record 35 of Set 3 | nelidovo
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | rio gallegos
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | batagay
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | bereda
# Processing Record 43 of Set 3 | pokrovskoye
# Processing Record 44 of Set 3 | bakchar
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | mehamn
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | kibre mengist
# Processing Record 49 of Set 3 | beloha
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | lokosovo
# Processing Record 2 of Set 4 | harper
# Processing Record 3 of Set 4 | ndola
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | tirau
# Processing Record 8 of Set 4 | urengoy
# Processing Record 9 of Set 4 | salym
# Processing Record 10 of Set 4 | bentiu
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | ambilobe
# Processing Record 13 of Set 4 | kodinsk
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | teya
# Processing Record 16 of Set 4 | natal
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | pitimbu
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | waipawa
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | hargeysa
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | salinopolis
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | aginskoye
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | grand-santi
# Processing Record 31 of Set 4 | sapao
# City not found. Skipping...
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | keffi
# Processing Record 34 of Set 4 | beringovskiy
# Processing Record 35 of Set 4 | egvekinot
# Processing Record 36 of Set 4 | honningsvag
# Processing Record 37 of Set 4 | cam ranh
# Processing Record 38 of Set 4 | chkalovsk
# Processing Record 39 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 4 | saint-francois
# Processing Record 41 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 42 of Set 4 | gigant
# Processing Record 43 of Set 4 | huambo
# Processing Record 44 of Set 4 | praia da vitoria
# Processing Record 45 of Set 4 | sibolga
# Processing Record 46 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 4 | omboue
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | hilo
# Processing Record 2 of Set 5 | marawi
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | northam
# Processing Record 5 of Set 5 | ilhabela
# Processing Record 6 of Set 5 | ixtapa
# Processing Record 7 of Set 5 | husavik
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | kashi
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | longview
# Processing Record 14 of Set 5 | saint-denis
# Processing Record 15 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 5 | ramnagar
# Processing Record 17 of Set 5 | pangai
# Processing Record 18 of Set 5 | melilla
# Processing Record 19 of Set 5 | adrar
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | naliya
# Processing Record 23 of Set 5 | alice springs
# Processing Record 24 of Set 5 | kaeo
# Processing Record 25 of Set 5 | aksha
# Processing Record 26 of Set 5 | ndele
# Processing Record 27 of Set 5 | qaqortoq
# Processing Record 28 of Set 5 | fort smith
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | general pico
# Processing Record 31 of Set 5 | mitsamiouli
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | la ronge
# Processing Record 34 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 5 | tilsonburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | matoury
# Processing Record 37 of Set 5 | yar-sale
# Processing Record 38 of Set 5 | matara
# Processing Record 39 of Set 5 | slevik
# City not found. Skipping...
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | tautira
# Processing Record 43 of Set 5 | roma
# Processing Record 44 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 5 | carnarvon
# Processing Record 46 of Set 5 | muisne
# Processing Record 47 of Set 5 | aksu
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | rantepao
# Processing Record 50 of Set 5 | paamiut
# Processing Record 1 of Set 6 | progreso
# Processing Record 2 of Set 6 | sinnamary
# Processing Record 3 of Set 6 | puquio
# Processing Record 4 of Set 6 | aguilar de la frontera
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | gat
# Processing Record 8 of Set 6 | sumbe
# Processing Record 9 of Set 6 | solnechnyy
# Processing Record 10 of Set 6 | cayenne
# Processing Record 11 of Set 6 | hirara
# Processing Record 12 of Set 6 | taseyevo
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | florida
# Processing Record 15 of Set 6 | eravur
# Processing Record 16 of Set 6 | mojo
# Processing Record 17 of Set 6 | umm kaddadah
# Processing Record 18 of Set 6 | kahului
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | takoradi
# Processing Record 21 of Set 6 | makakilo city
# Processing Record 22 of Set 6 | avera
# Processing Record 23 of Set 6 | kisiwani
# Processing Record 24 of Set 6 | jijiga
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | vizinga
# Processing Record 28 of Set 6 | feuchtwangen
# Processing Record 29 of Set 6 | mogok
# Processing Record 30 of Set 6 | gao
# Processing Record 31 of Set 6 | havre-saint-pierre
# Processing Record 32 of Set 6 | chake chake
# Processing Record 33 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | port moresby
# Processing Record 36 of Set 6 | luganville
# Processing Record 37 of Set 6 | mitzic
# Processing Record 38 of Set 6 | rosarito
# Processing Record 39 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | iskateley
# Processing Record 41 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 6 | allende
# Processing Record 43 of Set 6 | muli
# Processing Record 44 of Set 6 | ankang
# Processing Record 45 of Set 6 | zhigansk
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | nabire
# Processing Record 48 of Set 6 | cap malheureux
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 50 of Set 6 | inhambane
# Processing Record 1 of Set 7 | namie
# Processing Record 2 of Set 7 | carinhanha
# Processing Record 3 of Set 7 | dubreka
# Processing Record 4 of Set 7 | krasnovishersk
# Processing Record 5 of Set 7 | lima duarte
# Processing Record 6 of Set 7 | aras
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 7 | kaitangata
# Processing Record 10 of Set 7 | najran
# Processing Record 11 of Set 7 | eyl
# Processing Record 12 of Set 7 | shingu
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | linxia
# Processing Record 15 of Set 7 | gamba
# Processing Record 16 of Set 7 | narsaq
# Processing Record 17 of Set 7 | kenora
# Processing Record 18 of Set 7 | lamont
# Processing Record 19 of Set 7 | shellbrook
# Processing Record 20 of Set 7 | xai-xai
# Processing Record 21 of Set 7 | vygonichi
# Processing Record 22 of Set 7 | plettenberg bay
# Processing Record 23 of Set 7 | sitka
# Processing Record 24 of Set 7 | murindo
# Processing Record 25 of Set 7 | sao joao da barra
# Processing Record 26 of Set 7 | pantai remis
# Processing Record 27 of Set 7 | santa cruz
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | hokitika
# Processing Record 30 of Set 7 | flinders
# Processing Record 31 of Set 7 | kawalu
# Processing Record 32 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 7 | amos
# Processing Record 34 of Set 7 | newport
# Processing Record 35 of Set 7 | dunn
# Processing Record 36 of Set 7 | wagar
# Processing Record 37 of Set 7 | shenjiamen
# Processing Record 38 of Set 7 | frederico westphalen
# Processing Record 39 of Set 7 | souillac
# Processing Record 40 of Set 7 | aksarka
# Processing Record 41 of Set 7 | tucuman
# Processing Record 42 of Set 7 | vryburg
# Processing Record 43 of Set 7 | viborg
# Processing Record 44 of Set 7 | colquiri
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | aguimes
# Processing Record 47 of Set 7 | kargil
# Processing Record 48 of Set 7 | bubaque
# Processing Record 49 of Set 7 | bati
# Processing Record 50 of Set 7 | chokurdakh
# Processing Record 1 of Set 8 | thinadhoo
# Processing Record 2 of Set 8 | verkhnevilyuysk
# Processing Record 3 of Set 8 | sabang
# Processing Record 4 of Set 8 | esperance
# Processing Record 5 of Set 8 | laguna
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | kandrian
# Processing Record 8 of Set 8 | abnub
# Processing Record 9 of Set 8 | sabha
# Processing Record 10 of Set 8 | inongo
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | kenai
# Processing Record 13 of Set 8 | harsin
# Processing Record 14 of Set 8 | bonthe
# Processing Record 15 of Set 8 | namatanai
# Processing Record 16 of Set 8 | kununurra
# Processing Record 17 of Set 8 | sept-iles
# Processing Record 18 of Set 8 | port macquarie
# Processing Record 19 of Set 8 | harrisonburg
# Processing Record 20 of Set 8 | boali
# Processing Record 21 of Set 8 | evensk
# Processing Record 22 of Set 8 | vargem grande
# Processing Record 23 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 8 | ponta delgada
# Processing Record 25 of Set 8 | burnie
# Processing Record 26 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 27 of Set 8 | chippewa falls
# Processing Record 28 of Set 8 | victor harbor
# Processing Record 29 of Set 8 | tarko-sale
# Processing Record 30 of Set 8 | sao jose da coroa grande
# Processing Record 31 of Set 8 | henties bay
# Processing Record 32 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | limbazi
# Processing Record 35 of Set 8 | linlithgow
# Processing Record 36 of Set 8 | huarmey
# Processing Record 37 of Set 8 | terenos
# Processing Record 38 of Set 8 | binga
# Processing Record 39 of Set 8 | sale
# Processing Record 40 of Set 8 | camacha
# Processing Record 41 of Set 8 | majene
# Processing Record 42 of Set 8 | umm lajj
# Processing Record 43 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 8 | quepos
# Processing Record 45 of Set 8 | graulhet
# Processing Record 46 of Set 8 | nelson bay
# Processing Record 47 of Set 8 | cordoba
# Processing Record 48 of Set 8 | belle glade
# Processing Record 49 of Set 8 | chicama
# Processing Record 50 of Set 8 | olinda
# Processing Record 1 of Set 9 | rosetta
# Processing Record 2 of Set 9 | pueblo nuevo
# Processing Record 3 of Set 9 | doha
# Processing Record 4 of Set 9 | porto walter
# Processing Record 5 of Set 9 | victoria
# Processing Record 6 of Set 9 | marienburg
# Processing Record 7 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 8 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 9 | xining
# Processing Record 10 of Set 9 | sydney
# Processing Record 11 of Set 9 | kholodnyy
# Processing Record 12 of Set 9 | talavera
# Processing Record 13 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 9 | jawa
# Processing Record 15 of Set 9 | alta floresta
# Processing Record 16 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | gwembe
# Processing Record 18 of Set 9 | roald
# Processing Record 19 of Set 9 | mazatlan
# Processing Record 20 of Set 9 | corrente
# Processing Record 21 of Set 9 | quesnel
# Processing Record 22 of Set 9 | tongliao
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | moulins
# Processing Record 25 of Set 9 | shizuishan
# Processing Record 26 of Set 9 | tateyama
# Processing Record 27 of Set 9 | george
# Processing Record 28 of Set 9 | ayr
# Processing Record 29 of Set 9 | tanggu
# Processing Record 30 of Set 9 | sungaipenuh
# Processing Record 31 of Set 9 | sabana de torres
# Processing Record 32 of Set 9 | colotlan
# Processing Record 33 of Set 9 | tambacounda
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 9 | weihai
# Processing Record 37 of Set 9 | talnakh
# Processing Record 38 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 9 | orotukan
# Processing Record 40 of Set 9 | sheksna
# Processing Record 41 of Set 9 | san vicente
# Processing Record 42 of Set 9 | diamantino
# Processing Record 43 of Set 9 | port-gentil
# Processing Record 44 of Set 9 | adjumani
# Processing Record 45 of Set 9 | fairbanks
# Processing Record 46 of Set 9 | kabanjahe
# Processing Record 47 of Set 9 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | winchester
# Processing Record 49 of Set 9 | torbay
# Processing Record 50 of Set 9 | havoysund
# Processing Record 1 of Set 10 | ust-ilimsk
# Processing Record 2 of Set 10 | ligayan
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | luau
# Processing Record 5 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 10 | ust-kut
# Processing Record 7 of Set 10 | hasaki
# Processing Record 8 of Set 10 | woodmere
# Processing Record 9 of Set 10 | perth
# Processing Record 10 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 10 | mount pleasant
# Processing Record 12 of Set 10 | vanavara
# Processing Record 13 of Set 10 | ortisoara
# Processing Record 14 of Set 10 | pathein
# Processing Record 15 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 10 | songjianghe
# Processing Record 17 of Set 10 | bam
# Processing Record 18 of Set 10 | rudnya
# Processing Record 19 of Set 10 | hami
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 10 | hambantota
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | salvador
# Processing Record 24 of Set 10 | bathsheba
# Processing Record 25 of Set 10 | belmonte
# Processing Record 26 of Set 10 | conde
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | doctor juan leon mallorquin
# Processing Record 29 of Set 10 | mikuni
# Processing Record 30 of Set 10 | bowen
# Processing Record 31 of Set 10 | medicine hat
# Processing Record 32 of Set 10 | tokur
# Processing Record 33 of Set 10 | ust-nera
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | whitehorse
# Processing Record 36 of Set 10 | ambulu
# Processing Record 37 of Set 10 | banjar
# Processing Record 38 of Set 10 | port augusta
# Processing Record 39 of Set 10 | bad wildungen
# Processing Record 40 of Set 10 | key largo
# Processing Record 41 of Set 10 | cozumel
# Processing Record 42 of Set 10 | metapan
# Processing Record 43 of Set 10 | mikhaylovka
# Processing Record 44 of Set 10 | marquette
# Processing Record 45 of Set 10 | puerto madryn
# Processing Record 46 of Set 10 | atlantic city
# Processing Record 47 of Set 10 | oda
# Processing Record 48 of Set 10 | suzu
# City not found. Skipping...
# Processing Record 49 of Set 10 | lakes entrance
# Processing Record 50 of Set 10 | naze
# Processing Record 1 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 11 | norman wells
# Processing Record 3 of Set 11 | yei
# Processing Record 4 of Set 11 | wexford
# Processing Record 5 of Set 11 | port victoria
# Processing Record 6 of Set 11 | boa vista
# Processing Record 7 of Set 11 | north bend
# Processing Record 8 of Set 11 | acapulco
# Processing Record 9 of Set 11 | lensk
# Processing Record 10 of Set 11 | amuntai
# Processing Record 11 of Set 11 | palmer
# Processing Record 12 of Set 11 | panaba
# Processing Record 13 of Set 11 | aldan
# Processing Record 14 of Set 11 | scottsbluff
# Processing Record 15 of Set 11 | muravlenko
# Processing Record 16 of Set 11 | san andres
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | gainesville
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | aloleng
# Processing Record 21 of Set 11 | buta
# Processing Record 22 of Set 11 | goderich
# Processing Record 23 of Set 11 | limbang
# Processing Record 24 of Set 11 | kotturu
# Processing Record 25 of Set 11 | moree
# Processing Record 26 of Set 11 | gizo
# Processing Record 27 of Set 11 | sinjai
# Processing Record 28 of Set 11 | nanakuli
# Processing Record 29 of Set 11 | the valley
# Processing Record 30 of Set 11 | nyurba
# Processing Record 31 of Set 11 | lahad datu
# Processing Record 32 of Set 11 | weiser
# Processing Record 33 of Set 11 | sabirabad
# Processing Record 34 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 11 | rudbar
# Processing Record 36 of Set 11 | ontario
# Processing Record 37 of Set 11 | klaksvik
# Processing Record 38 of Set 11 | kartaly
# Processing Record 39 of Set 11 | jay
# Processing Record 40 of Set 11 | baruun-urt
# Processing Record 41 of Set 11 | santa maria
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | paralimni
# Processing Record 44 of Set 11 | grand gaube
# Processing Record 45 of Set 11 | pochutla
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | canutama
# Processing Record 48 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 11 | aquiraz
# Processing Record 1 of Set 12 | waddan
# Processing Record 2 of Set 12 | urumqi
# Processing Record 3 of Set 12 | rahatgarh
# Processing Record 4 of Set 12 | nioro
# Processing Record 5 of Set 12 | codrington
# Processing Record 6 of Set 12 | altay
# Processing Record 7 of Set 12 | faya
# Processing Record 8 of Set 12 | roblin
# Processing Record 9 of Set 12 | santa fe
# Processing Record 10 of Set 12 | vicksburg
# Processing Record 11 of Set 12 | suluq
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | itarema
# Processing Record 14 of Set 12 | korla
# Processing Record 15 of Set 12 | berikulskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | jalu
# Processing Record 17 of Set 12 | akureyri
# Processing Record 18 of Set 12 | copalillo
# Processing Record 19 of Set 12 | pekin
# Processing Record 20 of Set 12 | trincomalee
# Processing Record 21 of Set 12 | xuddur
# Processing Record 22 of Set 12 | oussouye
# Processing Record 23 of Set 12 | marabba
# Processing Record 24 of Set 12 | saint-paul
# Processing Record 25 of Set 12 | nimaparha
# Processing Record 26 of Set 12 | abu dhabi
# Processing Record 27 of Set 12 | killybegs
# Processing Record 28 of Set 12 | jumla
# Processing Record 29 of Set 12 | sorland
# Processing Record 30 of Set 12 | wloszczowa
# Processing Record 31 of Set 12 | sigli
# Processing Record 32 of Set 12 | dakar
# Processing Record 33 of Set 12 | yurla
# Processing Record 34 of Set 12 | mosquera
# Processing Record 35 of Set 12 | bhitarwar
# Processing Record 36 of Set 12 | prabumulih
# Processing Record 37 of Set 12 | banda aceh
# Processing Record 38 of Set 12 | kortkeros
# Processing Record 39 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 12 | minsk mazowiecki
# Processing Record 41 of Set 12 | paredon
# Processing Record 42 of Set 12 | komsomolskiy
# Processing Record 43 of Set 12 | broome
# Processing Record 44 of Set 12 | shelburne
# Processing Record 45 of Set 12 | mundo nuevo
# Processing Record 46 of Set 12 | qeshm
# Processing Record 47 of Set 12 | sunbury
# Processing Record 48 of Set 12 | aljezur
# Processing Record 49 of Set 12 | minnedosa
# Processing Record 50 of Set 12 | copiapo
# Processing Record 1 of Set 13 | talara
# Processing Record 2 of Set 13 | ahuimanu
# Processing Record 3 of Set 13 | valle de allende
# Processing Record 4 of Set 13 | aksay
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | dunedin
# Processing Record 7 of Set 13 | daru
# Processing Record 8 of Set 13 | maryville
# Processing Record 9 of Set 13 | palora
# Processing Record 10 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 13 | klyuchi
# Processing Record 12 of Set 13 | tutoia
# Processing Record 13 of Set 13 | bay roberts
# Processing Record 14 of Set 13 | biak
# Processing Record 15 of Set 13 | domoni
# Processing Record 16 of Set 13 | villazon
# Processing Record 17 of Set 13 | uige
# Processing Record 18 of Set 13 | broken hill
# Processing Record 19 of Set 13 | college
# Processing Record 20 of Set 13 | pacific grove
# Processing Record 21 of Set 13 | brownsville
# Processing Record 22 of Set 13 | shihezi
# Processing Record 23 of Set 13 | bauchi
# Processing Record 24 of Set 13 | polovinnoye
# Processing Record 25 of Set 13 | xilitla
# Processing Record 26 of Set 13 | mahanoro
# Processing Record 27 of Set 13 | katsuura
# Processing Record 28 of Set 13 | anadyr
# Processing Record 29 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 13 | arinos
# Processing Record 31 of Set 13 | itoman
# Processing Record 32 of Set 13 | nouadhibou
# Processing Record 33 of Set 13 | kautokeino
# Processing Record 34 of Set 13 | twin falls
# Processing Record 35 of Set 13 | yinchuan
# Processing Record 36 of Set 13 | dordrecht
# Processing Record 37 of Set 13 | lata
# Processing Record 38 of Set 13 | tabuk
# Processing Record 39 of Set 13 | talcahuano
# Processing Record 40 of Set 13 | cherskiy
# Processing Record 41 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 43 of Set 13 | berdigestyakh
# Processing Record 44 of Set 13 | bagdarin
# Processing Record 45 of Set 13 | scarborough
# Processing Record 46 of Set 13 | tacna
# Processing Record 47 of Set 13 | mastic beach
# Processing Record 48 of Set 13 | brae
# Processing Record 49 of Set 13 | oranjemund
# Processing Record 50 of Set 13 | comodoro rivadavia
# Processing Record 1 of Set 14 | batagay-alyta
# Processing Record 2 of Set 14 | biu
# Processing Record 3 of Set 14 | taoudenni
# Processing Record 4 of Set 14 | divnomorskoye
# Processing Record 5 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 14 | san quintin
# Processing Record 7 of Set 14 | geraldton
# Processing Record 8 of Set 14 | sonqor
# Processing Record 9 of Set 14 | severnoye
# Processing Record 10 of Set 14 | fukue
# Processing Record 11 of Set 14 | sao gabriel da cachoeira
# Processing Record 12 of Set 14 | ushtobe
# Processing Record 13 of Set 14 | dunmore town
# Processing Record 14 of Set 14 | isla vista
# Processing Record 15 of Set 14 | poum
# Processing Record 16 of Set 14 | te anau
# Processing Record 17 of Set 14 | kalabo
# Processing Record 18 of Set 14 | leeton
# Processing Record 19 of Set 14 | iquitos
# Processing Record 20 of Set 14 | gobabis
# Processing Record 21 of Set 14 | yarensk
# Processing Record 22 of Set 14 | kenitra
# Processing Record 23 of Set 14 | mendi
# Processing Record 24 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 25 of Set 14 | marsabit
# Processing Record 26 of Set 14 | xixiang
# Processing Record 27 of Set 14 | jhawarian
# Processing Record 28 of Set 14 | ankpa
# Processing Record 29 of Set 14 | bulaevo
# Processing Record 30 of Set 14 | la reforma
# Processing Record 31 of Set 14 | hervey bay
# Processing Record 32 of Set 14 | nhulunbuy
# Processing Record 33 of Set 14 | ritchie
# Processing Record 34 of Set 14 | chissamba
# Processing Record 35 of Set 14 | pilar
# Processing Record 36 of Set 14 | banepa
# Processing Record 37 of Set 14 | nargana
# Processing Record 38 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 39 of Set 14 | borama
# City not found. Skipping...
# Processing Record 40 of Set 14 | yatou
# Processing Record 41 of Set 14 | garden city
# Processing Record 42 of Set 14 | laje
# Processing Record 43 of Set 14 | upernavik
# Processing Record 44 of Set 14 | ancud
# Processing Record 45 of Set 14 | buritama
# Processing Record 46 of Set 14 | mount isa
# Processing Record 47 of Set 14 | nara
# Processing Record 48 of Set 14 | north platte
# Processing Record 49 of Set 14 | diffa
# Processing Record 50 of Set 14 | buraydah
# Processing Record 1 of Set 15 | mityana
# Processing Record 2 of Set 15 | meulaboh
# Processing Record 3 of Set 15 | whitianga
# Processing Record 4 of Set 15 | saint-joseph
# Processing Record 5 of Set 15 | marsa matruh
# Processing Record 6 of Set 15 | huesca
# Processing Record 7 of Set 15 | cabedelo
# Processing Record 8 of Set 15 | awjilah
# Processing Record 9 of Set 15 | sivas
# Processing Record 10 of Set 15 | cidreira
# Processing Record 11 of Set 15 | lufkin
# Processing Record 12 of Set 15 | barra do garcas
# Processing Record 13 of Set 15 | okhotsk
# Processing Record 14 of Set 15 | chopinzinho
# Processing Record 15 of Set 15 | ban mo
# Processing Record 16 of Set 15 | sapulpa
# Processing Record 17 of Set 15 | hualmay
# Processing Record 18 of Set 15 | redmond
# Processing Record 19 of Set 15 | pocoes
# Processing Record 20 of Set 15 | pucallpa
# Processing Record 21 of Set 15 | gillette
# Processing Record 22 of Set 15 | pemangkat
# Processing Record 23 of Set 15 | moose factory
# Processing Record 24 of Set 15 | vila do maio
# Processing Record 25 of Set 15 | champerico
# Processing Record 26 of Set 15 | dickinson
# Processing Record 27 of Set 15 | romulus
# Processing Record 28 of Set 15 | tarboro
# Processing Record 29 of Set 15 | yishui
# Processing Record 30 of Set 15 | inuvik
# Processing Record 31 of Set 15 | gua musang
# Processing Record 32 of Set 15 | yenagoa
# Processing Record 33 of Set 15 | payyannur
# Processing Record 34 of Set 15 | cayon
# Processing Record 35 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 15 | ekibastuz
# Processing Record 37 of Set 15 | katha
# City not found. Skipping...
# Processing Record 38 of Set 15 | gornopravdinsk
# Processing Record 39 of Set 15 | marystown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Praia Da Vitoria  38.7333  -27.0667     75.45        88          75
# 1            Hasaki  35.7333  140.8333     73.29        90         100
# 2      Puerto Ayora  -0.7393  -90.3518     75.54        77          81
# 3          Tasiilaq  65.6145  -37.6368     39.36        88         100
# 4           Ushuaia -54.8000  -68.3000     36.84        77          13
# 5           Qaanaaq  77.4840  -69.3632     38.43        60          83
# 6            Albany  42.6001  -73.9662     88.09        70          97
# 7           Mataura -46.1927  168.8643     39.67        97         100
# 8       Port Alfred -33.5906   26.8910     56.44        55          21
# 9        Butaritari   3.0707  172.7902     82.38        78          92
#
#    Wind Speed Country      Weather Description                 Date
# 0        3.60      PT  light intensity drizzle  2021-07-06 17:01:19
# 1        4.68      JP               light rain  2021-07-06 17:01:20
# 2       10.00      EC            broken clouds  2021-07-06 17:01:20
# 3        4.63      GL          overcast clouds  2021-07-06 17:01:20
# 4        2.73      AR               few clouds  2021-07-06 17:00:38
# 5        6.49      GL            broken clouds  2021-07-06 17:01:21
# 6        1.01      US          overcast clouds  2021-07-06 16:59:24
# 7        6.31      NZ               light rain  2021-07-06 17:01:21
# 8        1.21      ZA               few clouds  2021-07-06 17:01:22
# 9       17.02      KI               light rain  2021-07-06 17:01:22

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0  Praia Da Vitoria      PT  2021-07-06 17:01:19  38.7333  -27.0667     75.45
# 1            Hasaki      JP  2021-07-06 17:01:20  35.7333  140.8333     73.29
# 2      Puerto Ayora      EC  2021-07-06 17:01:20  -0.7393  -90.3518     75.54
# 3          Tasiilaq      GL  2021-07-06 17:01:20  65.6145  -37.6368     39.36
# 4           Ushuaia      AR  2021-07-06 17:00:38 -54.8000  -68.3000     36.84
# 5           Qaanaaq      GL  2021-07-06 17:01:21  77.4840  -69.3632     38.43
# 6            Albany      US  2021-07-06 16:59:24  42.6001  -73.9662     88.09
# 7           Mataura      NZ  2021-07-06 17:01:21 -46.1927  168.8643     39.67
# 8       Port Alfred      ZA  2021-07-06 17:01:22 -33.5906   26.8910     56.44
# 9        Butaritari      KI  2021-07-06 17:01:22   3.0707  172.7902     82.38
#
#    Humidity  Cloudiness  Wind Speed      Weather Description
# 0        88          75        3.60  light intensity drizzle
# 1        90         100        4.68               light rain
# 2        77          81       10.00            broken clouds
# 3        88         100        4.63          overcast clouds
# 4        77          13        2.73               few clouds
# 5        60          83        6.49            broken clouds
# 6        70          97        1.01          overcast clouds
# 7        97         100        6.31               light rain
# 8        55          21        1.21               few clouds
# 9        78          92       17.02               light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
